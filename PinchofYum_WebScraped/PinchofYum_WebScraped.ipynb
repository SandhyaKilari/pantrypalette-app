# %% [markdown]
# ### Web Scraping - "pinchofyum"

# %%
# !pip install selenium
# !pip install webdriver-manager
# Out:
# Requirement already satisfied: selenium in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (4.25.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from selenium) (0.27.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: typing_extensions~=4.9 in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (24.2.0)
# Requirement already satisfied: sortedcontainers in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: webdriver-manager in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (4.0.2)
# Requirement already satisfied: requests in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from webdriver-manager) (2.31.0)
# Requirement already satisfied: python-dotenv in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from webdriver-manager) (0.21.0)
# Requirement already satisfied: packaging in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from webdriver-manager) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from requests->webdriver-manager) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from requests->webdriver-manager) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/madhuryashankar/anaconda3/lib/python3.11/site-packages (from requests->webdriver-manager) (2023.7.22)

# %%
import requests
from bs4 import BeautifulSoup
import time
import datetime
import pandas as pd
import logging
import traceback
import os

BASE_URL = 'https://pinchofyum.com'
RECIPE_LIST_URL = f'{BASE_URL}/recipes/all'
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36'
}

cur_time = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
log_file_name = f"scraper_{cur_time}.log"
logging.basicConfig(level=logging.INFO, filename=log_file_name, filemode='w', format='%(asctime)s - %(message)s')

def get_number_of_pages():
    """
    Fetches the total number of pages from the recipe list URL.

    :return:
        int: Total number of pages.
    """
    response = requests.get(RECIPE_LIST_URL, headers=HEADERS)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the span with class 'page-numbers dots'
    dots_span = soup.find('span', class_='page-numbers dots')
    if dots_span:
        # Find the next 'a' sibling after the dots span
        next_page_link = dots_span.find_next('a', class_='page-numbers')
        if next_page_link:
            total_pages = int(next_page_link.get_text(strip=True))
            return total_pages

    return 1  # Default to 1 if no pagination is found

def get_recipe_links(total_pages):
    """
    Fetches all the recipe links from the recipe list URL across all pages.

    :param total_pages: Total number of pages.
    :return:
        List[str]: List of recipe URLs.
    """
    recipe_links = []
    for page in range(1, total_pages + 1):
        # Sleep to be polite and prevent IP blocking
        time.sleep(5)
        page_url = f"{RECIPE_LIST_URL}/page/{page}"
        print(f"Fetching page URL: {page_url}")
        page_response = requests.get(page_url, headers=HEADERS)
        if page_response.status_code != 200:
            print(f"Failed to fetch page {page} (status code: {page_response.status_code})")
            continue

        page_soup = BeautifulSoup(page_response.content, "html.parser")
        articles_container = page_soup.find("div", class_="grid grid-cols-12 gap-4")
        
        # If the structure changes or doesn't exist, skip
        if not articles_container:
            print(f"No recipes found on page {page}")
            continue

        articles = articles_container.find_all("article")
        for article in articles:
            link_tag = article.find("a")
            if link_tag and link_tag.get("href"):
                recipe_links.append(link_tag["href"])

    return recipe_links

def get_recipes(recipe_url):
    """
    Fetches recipe details from an individual recipe page.

    :param recipe_url: URL of the recipe to scrape.
    :return:
        dict or None: Dictionary of recipe details if successful, else None.
    """
    try:
        print(f"Getting recipe details from {recipe_url}")
        recipe_response = requests.get(recipe_url, headers=HEADERS)
        if recipe_response.status_code != 200:
            print(f"Failed to fetch recipe URL (status code: {recipe_response.status_code})")
            return None
        
        recipe_soup = BeautifulSoup(recipe_response.content, "html.parser")
        recipe_div = recipe_soup.find("div", class_="tasty-recipes")
        
        # If the specific recipe container doesn't exist, skip
        if not recipe_div:
            print(f"No 'tasty-recipes' div found at {recipe_url}")
            return None
        
        # Extract fields
        recipe_img_tag = recipe_div.find("img", class_="attachment-thumbnail size-thumbnail")
        recipe_img = recipe_img_tag["src"] if recipe_img_tag else ""

        title_tag = recipe_div.find("h2", class_="tasty-recipes-title")
        recipe_title = title_tag.get_text(strip=True) if title_tag else "No Title"

        total_time_tag = recipe_div.find("span", class_="tasty-recipes-total-time")
        recipe_total_time = total_time_tag.get_text(strip=True) if total_time_tag else "Not specified"

        # Description
        try:
            desc_body = recipe_div.find("div", class_="tasty-recipes-description-body")
            recipe_description = desc_body.find("p").get_text(strip=True)
        except:
            recipe_description = ""

        # Ingredients
        ingredients = []
        recipe_ingredients_header = recipe_div.find("div", class_="tasty-recipes-ingredients-header")
        if recipe_ingredients_header:
            recipe_ingredients = recipe_ingredients_header.find_next_sibling("div")
            if recipe_ingredients:
                li_tags = recipe_ingredients.find_all("li")
                for li_tag in li_tags:
                    # The code assumes each `li` has an `input` with aria-label
                    input_tag = li_tag.find("input")
                    if input_tag and input_tag.get("aria-label"):
                        ingredients.append(input_tag["aria-label"])

        # Instructions
        instructions = []
        instructions_header = recipe_div.find("div", class_="tasty-recipes-instructions-header")
        if instructions_header:
            instructions_div = instructions_header.find_next_sibling("div")
            if instructions_div:
                instruction_items = instructions_div.find_all("li")
                for item in instruction_items:
                    instructions.append(item.get_text(strip=True))

        recipe = {
            'image': recipe_img,
            'title': recipe_title,
            'description': recipe_description,
            'total_time': recipe_total_time,
            'ingredients': ingredients,
            'instructions': instructions
        }
        return recipe

    except Exception as e:
        traceback_info = traceback.format_exc()
        print(f"Exception {e} occurred while scraping {recipe_url}")
        print(f"Traceback info: {traceback_info}")
        return None

def scrape_recipes():
    """
    Scrapes recipes from the website and saves to CSV.
    """
    total_pages = get_number_of_pages()
    print(f'Total number of pages to scrape: {total_pages}')

    # Get links of all recipes
    recipe_urls = get_recipe_links(total_pages)

    for recipe_url in recipe_urls:
        logging.info(f"Started scraping {recipe_url}")
        # Sleep to avoid too-frequent requests
        time.sleep(120)
        recipe_data = get_recipes(recipe_url)
        if recipe_data:
            print(f"Successfully scraped {recipe_url}")
            logging.info(f"Completed scraping {recipe_url}")
            save_recipe_to_csv(recipe_data)
        else:
            logging.error(f"Failed to scrape {recipe_url}")

def save_recipe_to_csv(recipe, filename='recipes.csv'):
    """
    Saves a single recipe to a CSV file. Appends if file exists, otherwise creates it.
    """
    df = pd.DataFrame([recipe])
    try:
        file_exists = os.path.isfile(filename)
        df.to_csv(filename, mode='a', header=not file_exists, index=False)
        print(f"Recipe saved to {filename}")
    except PermissionError:
        logging.error(f"Permission denied for file {filename}")
    except OSError as e:
        logging.error(f"Error: {e}")
    except Exception as e:
        logging.error(f"Unexpected error occurred: {e}")

if __name__ == "__main__":
    scrape_recipes()
# Out:
# Total number of pages to scrape: 107
# Fetching page URL: https://pinchofyum.com/recipes/all/page/1
# Fetching page URL: https://pinchofyum.com/recipes/all/page/2
# Fetching page URL: https://pinchofyum.com/recipes/all/page/3
# Fetching page URL: https://pinchofyum.com/recipes/all/page/4
# Fetching page URL: https://pinchofyum.com/recipes/all/page/5
# Fetching page URL: https://pinchofyum.com/recipes/all/page/6
# Fetching page URL: https://pinchofyum.com/recipes/all/page/7
# Fetching page URL: https://pinchofyum.com/recipes/all/page/8
# Fetching page URL: https://pinchofyum.com/recipes/all/page/9
# Fetching page URL: https://pinchofyum.com/recipes/all/page/10
# Fetching page URL: https://pinchofyum.com/recipes/all/page/11
# Fetching page URL: https://pinchofyum.com/recipes/all/page/12
# Fetching page URL: https://pinchofyum.com/recipes/all/page/13
# Fetching page URL: https://pinchofyum.com/recipes/all/page/14
# Fetching page URL: https://pinchofyum.com/recipes/all/page/15
# Fetching page URL: https://pinchofyum.com/recipes/all/page/16
# Fetching page URL: https://pinchofyum.com/recipes/all/page/17
# Fetching page URL: https://pinchofyum.com/recipes/all/page/18
# Fetching page URL: https://pinchofyum.com/recipes/all/page/19
# Fetching page URL: https://pinchofyum.com/recipes/all/page/20
# Fetching page URL: https://pinchofyum.com/recipes/all/page/21
# Fetching page URL: https://pinchofyum.com/recipes/all/page/22
# Fetching page URL: https://pinchofyum.com/recipes/all/page/23
# Fetching page URL: https://pinchofyum.com/recipes/all/page/24
# Fetching page URL: https://pinchofyum.com/recipes/all/page/25
# Fetching page URL: https://pinchofyum.com/recipes/all/page/26
# Fetching page URL: https://pinchofyum.com/recipes/all/page/27
# Fetching page URL: https://pinchofyum.com/recipes/all/page/28
# Fetching page URL: https://pinchofyum.com/recipes/all/page/29
# Fetching page URL: https://pinchofyum.com/recipes/all/page/30
# Fetching page URL: https://pinchofyum.com/recipes/all/page/31
# Fetching page URL: https://pinchofyum.com/recipes/all/page/32
# Fetching page URL: https://pinchofyum.com/recipes/all/page/33
# Fetching page URL: https://pinchofyum.com/recipes/all/page/34
# Fetching page URL: https://pinchofyum.com/recipes/all/page/35
# Fetching page URL: https://pinchofyum.com/recipes/all/page/36
# Fetching page URL: https://pinchofyum.com/recipes/all/page/37
# Fetching page URL: https://pinchofyum.com/recipes/all/page/38
# Fetching page URL: https://pinchofyum.com/recipes/all/page/39
# Fetching page URL: https://pinchofyum.com/recipes/all/page/40
# Fetching page URL: https://pinchofyum.com/recipes/all/page/41
# Fetching page URL: https://pinchofyum.com/recipes/all/page/42
# Fetching page URL: https://pinchofyum.com/recipes/all/page/43
# Fetching page URL: https://pinchofyum.com/recipes/all/page/44
# Fetching page URL: https://pinchofyum.com/recipes/all/page/45
# Fetching page URL: https://pinchofyum.com/recipes/all/page/46
# Fetching page URL: https://pinchofyum.com/recipes/all/page/47
# Fetching page URL: https://pinchofyum.com/recipes/all/page/48
# Fetching page URL: https://pinchofyum.com/recipes/all/page/49
# Fetching page URL: https://pinchofyum.com/recipes/all/page/50
# Fetching page URL: https://pinchofyum.com/recipes/all/page/51
# Fetching page URL: https://pinchofyum.com/recipes/all/page/52
# Fetching page URL: https://pinchofyum.com/recipes/all/page/53
# Fetching page URL: https://pinchofyum.com/recipes/all/page/54
# Fetching page URL: https://pinchofyum.com/recipes/all/page/55
# Fetching page URL: https://pinchofyum.com/recipes/all/page/56
# Fetching page URL: https://pinchofyum.com/recipes/all/page/57
# Fetching page URL: https://pinchofyum.com/recipes/all/page/58
# Fetching page URL: https://pinchofyum.com/recipes/all/page/59
# Fetching page URL: https://pinchofyum.com/recipes/all/page/60
# Fetching page URL: https://pinchofyum.com/recipes/all/page/61
# Fetching page URL: https://pinchofyum.com/recipes/all/page/62
# Fetching page URL: https://pinchofyum.com/recipes/all/page/63
# Fetching page URL: https://pinchofyum.com/recipes/all/page/64
# Fetching page URL: https://pinchofyum.com/recipes/all/page/65
# Fetching page URL: https://pinchofyum.com/recipes/all/page/66
# Fetching page URL: https://pinchofyum.com/recipes/all/page/67
# Fetching page URL: https://pinchofyum.com/recipes/all/page/68
# Fetching page URL: https://pinchofyum.com/recipes/all/page/69
# Fetching page URL: https://pinchofyum.com/recipes/all/page/70
# Fetching page URL: https://pinchofyum.com/recipes/all/page/71
# Fetching page URL: https://pinchofyum.com/recipes/all/page/72
# Fetching page URL: https://pinchofyum.com/recipes/all/page/73
# Fetching page URL: https://pinchofyum.com/recipes/all/page/74
# Fetching page URL: https://pinchofyum.com/recipes/all/page/75
# Fetching page URL: https://pinchofyum.com/recipes/all/page/76
# Fetching page URL: https://pinchofyum.com/recipes/all/page/77
# Fetching page URL: https://pinchofyum.com/recipes/all/page/78
# Fetching page URL: https://pinchofyum.com/recipes/all/page/79
# Fetching page URL: https://pinchofyum.com/recipes/all/page/80
# Fetching page URL: https://pinchofyum.com/recipes/all/page/81
# Fetching page URL: https://pinchofyum.com/recipes/all/page/82
# Fetching page URL: https://pinchofyum.com/recipes/all/page/83
# Fetching page URL: https://pinchofyum.com/recipes/all/page/84
# Fetching page URL: https://pinchofyum.com/recipes/all/page/85
# Fetching page URL: https://pinchofyum.com/recipes/all/page/86
# Fetching page URL: https://pinchofyum.com/recipes/all/page/87
# Fetching page URL: https://pinchofyum.com/recipes/all/page/88
# Fetching page URL: https://pinchofyum.com/recipes/all/page/89
# Fetching page URL: https://pinchofyum.com/recipes/all/page/90
# Fetching page URL: https://pinchofyum.com/recipes/all/page/91
# Fetching page URL: https://pinchofyum.com/recipes/all/page/92
# Fetching page URL: https://pinchofyum.com/recipes/all/page/93
# Fetching page URL: https://pinchofyum.com/recipes/all/page/94
# Fetching page URL: https://pinchofyum.com/recipes/all/page/95
# Fetching page URL: https://pinchofyum.com/recipes/all/page/96
# Fetching page URL: https://pinchofyum.com/recipes/all/page/97
# Fetching page URL: https://pinchofyum.com/recipes/all/page/98
# Fetching page URL: https://pinchofyum.com/recipes/all/page/99
# Fetching page URL: https://pinchofyum.com/recipes/all/page/100
# Fetching page URL: https://pinchofyum.com/recipes/all/page/101
# Fetching page URL: https://pinchofyum.com/recipes/all/page/102
# Fetching page URL: https://pinchofyum.com/recipes/all/page/103
# Fetching page URL: https://pinchofyum.com/recipes/all/page/104
# Fetching page URL: https://pinchofyum.com/recipes/all/page/105
# Fetching page URL: https://pinchofyum.com/recipes/all/page/106
# Fetching page URL: https://pinchofyum.com/recipes/all/page/107
# Getting recipe details from https://pinchofyum.com/ridiculously-good-air-fryer-broccoli
# Successfully scraped https://pinchofyum.com/ridiculously-good-air-fryer-broccoli
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/my-new-favorite-pizza-has-a-cottage-cheese-crust
# Successfully scraped https://pinchofyum.com/my-new-favorite-pizza-has-a-cottage-cheese-crust
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/mixed-berry-muffins-with-sugary-tops
# Successfully scraped https://pinchofyum.com/mixed-berry-muffins-with-sugary-tops
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/sweet-potato-soup-with-roasted-cauliflower-crumbles
# Successfully scraped https://pinchofyum.com/sweet-potato-soup-with-roasted-cauliflower-crumbles
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/french-toast-crepes
# Successfully scraped https://pinchofyum.com/french-toast-crepes
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/buffalo-chicken-burgers-with-whipped-feta-spread
# Successfully scraped https://pinchofyum.com/buffalo-chicken-burgers-with-whipped-feta-spread
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/crockpot-chicken-bowls-with-yellow-rice-and-cilantro-pesto
# Successfully scraped https://pinchofyum.com/crockpot-chicken-bowls-with-yellow-rice-and-cilantro-pesto
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/cilantro-pesto
# Successfully scraped https://pinchofyum.com/cilantro-pesto
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/thai-peanut-chicken-bowls
# Successfully scraped https://pinchofyum.com/thai-peanut-chicken-bowls
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/gingery-cranberry-salsa
# Successfully scraped https://pinchofyum.com/gingery-cranberry-salsa
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/debs-ranch-crackers
# Successfully scraped https://pinchofyum.com/debs-ranch-crackers
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/dulce-de-leche-tiramisu
# Successfully scraped https://pinchofyum.com/dulce-de-leche-tiramisu
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/lemon-rosemary-chicken-soup
# Successfully scraped https://pinchofyum.com/lemon-rosemary-chicken-soup
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/brussels-sprouts-with-gochujang-butter
# Successfully scraped https://pinchofyum.com/brussels-sprouts-with-gochujang-butter
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/incredible-arancini
# Successfully scraped https://pinchofyum.com/incredible-arancini
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/bang-bang-salmon-with-avocado-cucumber-salsa
# Successfully scraped https://pinchofyum.com/bang-bang-salmon-with-avocado-cucumber-salsa
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/scallion-pancake-with-eggs
# Successfully scraped https://pinchofyum.com/scallion-pancake-with-eggs
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/homemade-alfredo-sauce
# Successfully scraped https://pinchofyum.com/homemade-alfredo-sauce
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/sticky-gochujang-tofu-with-herbs-and-peanuts
# Successfully scraped https://pinchofyum.com/sticky-gochujang-tofu-with-herbs-and-peanuts
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/chicken-tacos
# Successfully scraped https://pinchofyum.com/chicken-tacos
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/garlic-and-black-pepper-beef-skewers
# Successfully scraped https://pinchofyum.com/garlic-and-black-pepper-beef-skewers
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/chicken-with-coconut-kale
# Successfully scraped https://pinchofyum.com/chicken-with-coconut-kale
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/ricotta-meatballs-with-the-crispy-topping
# Successfully scraped https://pinchofyum.com/ricotta-meatballs-with-the-crispy-topping
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/welcome-to-the-sos-series
# No 'tasty-recipes' div found at https://pinchofyum.com/welcome-to-the-sos-series
# Getting recipe details from https://pinchofyum.com/spicy-shrimp-with-peach-salad
# Successfully scraped https://pinchofyum.com/spicy-shrimp-with-peach-salad
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/party-brownies
# Successfully scraped https://pinchofyum.com/party-brownies
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/how-you-should-be-doing-oat-bran-for-breakfast
# Successfully scraped https://pinchofyum.com/how-you-should-be-doing-oat-bran-for-breakfast
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/gorgeous-peach-salad
# Successfully scraped https://pinchofyum.com/gorgeous-peach-salad
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/honey-chipotle-chicken-skewers
# Successfully scraped https://pinchofyum.com/honey-chipotle-chicken-skewers
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/amazing-green-rice
# Successfully scraped https://pinchofyum.com/amazing-green-rice
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/super-yummy-chicken-salad
# Successfully scraped https://pinchofyum.com/super-yummy-chicken-salad
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/avocado-caesar-green-beans
# Successfully scraped https://pinchofyum.com/avocado-caesar-green-beans
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/two-huge-double-chocolate-cookies
# Successfully scraped https://pinchofyum.com/two-huge-double-chocolate-cookies
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/big-yummy-italian-salad
# Successfully scraped https://pinchofyum.com/big-yummy-italian-salad
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/crispy-rice-salad-with-cucumbers-and-herbs
# Successfully scraped https://pinchofyum.com/crispy-rice-salad-with-cucumbers-and-herbs
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/incredible-gochujang-sauce
# Successfully scraped https://pinchofyum.com/incredible-gochujang-sauce
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/ridiculously-good-air-fryer-salmon
# Successfully scraped https://pinchofyum.com/ridiculously-good-air-fryer-salmon
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/33-things-you-absolutely-need-to-be-buying-at-trader-joes
# No 'tasty-recipes' div found at https://pinchofyum.com/33-things-you-absolutely-need-to-be-buying-at-trader-joes
# Getting recipe details from https://pinchofyum.com/two-huge-chocolate-chip-cookies
# Successfully scraped https://pinchofyum.com/two-huge-chocolate-chip-cookies
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/marry-me-chicken
# Successfully scraped https://pinchofyum.com/marry-me-chicken
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/ridiculously-good-air-fryer-tofu
# Successfully scraped https://pinchofyum.com/ridiculously-good-air-fryer-tofu
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/baked-tortellini-with-sausage
# Successfully scraped https://pinchofyum.com/baked-tortellini-with-sausage
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/butter-cauliflower-and-chickpeas-with-mint-cilantro-sauce
# Successfully scraped https://pinchofyum.com/butter-cauliflower-and-chickpeas-with-mint-cilantro-sauce
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/shortcut-sesame-butter-noodles
# Successfully scraped https://pinchofyum.com/shortcut-sesame-butter-noodles
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/banza-chicken-bowls-with-calabrian-chili-sauce
# Successfully scraped https://pinchofyum.com/banza-chicken-bowls-with-calabrian-chili-sauce
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/ridiculously-good-air-fryer-chicken-breast
# Successfully scraped https://pinchofyum.com/ridiculously-good-air-fryer-chicken-breast
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/super-creamy-white-chicken-chili-with-seasoned-tots
# Successfully scraped https://pinchofyum.com/super-creamy-white-chicken-chili-with-seasoned-tots
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/roasted-mushroom-sandwich-with-horseradish-aioli
# Successfully scraped https://pinchofyum.com/roasted-mushroom-sandwich-with-horseradish-aioli
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/gnocchi-with-creamy-mushroom-sauce
# Successfully scraped https://pinchofyum.com/gnocchi-with-creamy-mushroom-sauce
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/easy-instant-pot-applesauce
# Successfully scraped https://pinchofyum.com/easy-instant-pot-applesauce
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/slow-cooker-texas-style-chili
# Successfully scraped https://pinchofyum.com/slow-cooker-texas-style-chili
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/5-ingredient-tomato-soup
# Successfully scraped https://pinchofyum.com/5-ingredient-tomato-soup
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/house-favorite-garlic-bread
# Successfully scraped https://pinchofyum.com/house-favorite-garlic-bread
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/pumpkin-muffins-with-maple-cream-cheese-filling
# Successfully scraped https://pinchofyum.com/pumpkin-muffins-with-maple-cream-cheese-filling
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/swedish-pancakes
# Successfully scraped https://pinchofyum.com/swedish-pancakes
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/roasted-corn-and-fried-egg-tacos
# Successfully scraped https://pinchofyum.com/roasted-corn-and-fried-egg-tacos
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/chimichurri-shrimp-with-tomatoes
# Successfully scraped https://pinchofyum.com/chimichurri-shrimp-with-tomatoes
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/creamy-baked-orzo-with-meatballs
# Successfully scraped https://pinchofyum.com/creamy-baked-orzo-with-meatballs
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/kale-apple-salad-crispy-shallots
# Successfully scraped https://pinchofyum.com/kale-apple-salad-crispy-shallots
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/chicken-wontons-in-spicy-chili-sauce
# Successfully scraped https://pinchofyum.com/chicken-wontons-in-spicy-chili-sauce
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/red-curry-chicken-stir-fry-with-spicy-cashew-sauce
# Successfully scraped https://pinchofyum.com/red-curry-chicken-stir-fry-with-spicy-cashew-sauce
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/feel-good-zucchini-muffins
# Successfully scraped https://pinchofyum.com/feel-good-zucchini-muffins
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/pumpkin-caramel-monkey-bread
# Successfully scraped https://pinchofyum.com/pumpkin-caramel-monkey-bread
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/english-muffin-baklava
# Successfully scraped https://pinchofyum.com/english-muffin-baklava
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/roasted-peanut-kale-crunch-salad
# Successfully scraped https://pinchofyum.com/roasted-peanut-kale-crunch-salad
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/aji-verde
# Successfully scraped https://pinchofyum.com/aji-verde
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/my-go-to-pickled-red-onions
# Successfully scraped https://pinchofyum.com/my-go-to-pickled-red-onions
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/gochujang-chicken-burgers-with-kimchi-bacon-jam
# Successfully scraped https://pinchofyum.com/gochujang-chicken-burgers-with-kimchi-bacon-jam
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/grilled-chicken-with-pepperoncini-garlic-butter
# Successfully scraped https://pinchofyum.com/grilled-chicken-with-pepperoncini-garlic-butter
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/blueberry-matcha-latte
# Successfully scraped https://pinchofyum.com/blueberry-matcha-latte
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/very-incredible-basil-sauce
# Successfully scraped https://pinchofyum.com/very-incredible-basil-sauce
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/trader-joes-sun-dried-tomato-focaccia-turkey-sandwich
# Successfully scraped https://pinchofyum.com/trader-joes-sun-dried-tomato-focaccia-turkey-sandwich
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/garlic-shrimp-and-tomatoes-on-parmesan-orzo
# Successfully scraped https://pinchofyum.com/garlic-shrimp-and-tomatoes-on-parmesan-orzo
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/salmon-with-basil-sauce-and-tomato-salad
# Successfully scraped https://pinchofyum.com/salmon-with-basil-sauce-and-tomato-salad
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/chicken-teriyaki-burgers
# Successfully scraped https://pinchofyum.com/chicken-teriyaki-burgers
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/kimchi-tuna-salad-wrap
# Successfully scraped https://pinchofyum.com/kimchi-tuna-salad-wrap
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/chili-crunch-tofu
# Successfully scraped https://pinchofyum.com/chili-crunch-tofu
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/a-really-good-non-alcoholic-margarita
# Successfully scraped https://pinchofyum.com/a-really-good-non-alcoholic-margarita
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/avocado-mojo-bowls-with-sweet-potato-and-chicken
# Successfully scraped https://pinchofyum.com/avocado-mojo-bowls-with-sweet-potato-and-chicken
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/pickled-strawberries
# Successfully scraped https://pinchofyum.com/pickled-strawberries
# Recipe saved to recipes.csv
# Getting recipe details from https://pinchofyum.com/salmon-tacos
# Successfully scraped https://pinchofyum.com/salmon-tacos
# Recipe saved to recipes.csv
